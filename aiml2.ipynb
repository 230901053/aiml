# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
df=pd.read_excel("aiml1.xlsx")
df
plt.xlabel('POWER RATING')
plt.ylabel('AMOUNT OF COPPER')
plt.title('COPPER PREDICTION IN GENERATOR')
plt.hist(df[['power_rating','weight_of_copper']])
from sklearn.model_selection import train_test_split
x=np.array(df['power_rating'])
y=df['weight_of_copper']
x_train, x_test,y_train,y_test=train_test_split(x.reshape(-1,1),y,test_size=0.3)
len(x_train)
len(y_train)
len(x_test)
len(y_test)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
LinearRegression
LinearRegression()
x_pred=model.predict(x_test)
model.score(x_test, y_test)
model.predict([[6.29]])
# Out:
# array([19.43608742])

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)
plt.scatter(x,y)
def myfunc(x):
    return slope * x + intercept
mymodel = list(map(myfunc, x))
plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()

# %%
x=x.reshape(-1,1)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(x_train,y_train.values.ravel())
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([42.40133966, 79.80864956, 26.50248301, 20.15793926, 55.72038184,
#        35.45683906, 45.74609913, 65.93464729, 28.79731798, 34.69189407,
#        33.68696634, 72.1142029 , 33.92694908, 50.23077662, 33.05701164,
#        46.64603441, 24.22264696, 81.29354278, 38.9215899 , 29.78724679,
#        43.72124474, 71.33425899, 35.44184014, 71.64923634, 48.58089526,
#        33.56697497, 22.58776453, 69.44439489, 82.67344354, 79.71865603,
#        46.3610549 , 25.34756606, 49.04586183, 39.58154244])

# %%
print("Intercept:",intercept)
print("Slope:",slope)
# Out:
# Intercept: 10.001407532332053
# Slope: 1.4999581702277132

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
print("r2_score:",r2_score(y_test,y_pred))
# Out:
# r2_score: 0.9999998999368555

# %%
new_powerrating=[[44.4]]
x=clf.predict(new_powerrating)
print(x)
# Out:
# [76.59888039]

# %%
new_powerrating=[[56]]
x=clf.predict(new_powerrating)
print(x)
# Out:
# [93.99762918]
